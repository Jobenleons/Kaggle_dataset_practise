# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Datasets/link2/House_Price.csv")

# %%
df.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df.isnull().sum()
# Out:
# price          0
# crime_rate     0
# resid_area     0
# air_qual       0
# room_num       0
# age            0
# dist1          0
# dist2          0
# dist3          0
# dist4          0
# teachers       0
# poor_prop      0
# airport        0
# n_hos_beds     8
# n_hot_rooms    0
# waterbody      0
# rainfall       0
# bus_ter        0
# parks          0
# dtype: int64

# %% [markdown]
# Hence there is no null element.

# %%
y = df.iloc[:,0].values
X = df.iloc[:,1:]

# %%
y= y.reshape(-1,1)

# %%
y
# Out:
# array([[24. ],
#        [21.6],
#        [34.7],
#        [33.4],
#        [36.2],
#        [28.7],
#        [22.9],
#        [22.1],
#        [16.5],
#        [18.9],
#        [15. ],
#        [18.9],
#        [21.7],
#        [20.4],
#        [18.2],
#        [19.9],
#        [23.1],
#        [17.5],
#        [20.2],
#        [18.2],
#        [13.6],
#        [19.6],
#        [15.2],
#        [14.5],
#        [15.6],
#        [13.9],
#        [16.6],
#        [14.8],
#        [18.4],
#        [21. ],
#        [12.7],
#        [14.5],
#        [13.2],
#        [13.1],
#        [13.5],
#        [18.9],
#        [20. ],
#        [21. ],
#        [24.2],
#        [30.8],
#        [34.9],
#        [26.6],
#        [25.3],
#        [24.7],
#        [21.2],
#        [19.3],
#        [20. ],
#        [16.6],
#        [14.4],
#        [19.4],
#        [19.7],
#        [20.5],
#        [25. ],
#        [23.4],
#        [18.9],
#        [35.4],
#        [24.7],
#        [31.6],
# ...

# %%
X.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  dist3  \
# 0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81   4.18
# 1     0.02731       37.07     0.469     6.421  78.9   4.99   4.70   5.12
# 2     0.02729       37.07     0.469     7.185  61.1   5.03   4.86   5.01
# 3     0.03237       32.18     0.458     6.998  45.8   6.21   5.93   6.16
# 4     0.06905       32.18     0.458     7.147  54.2   6.16   5.86   6.37
#
#    dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms waterbody  \
# 0   4.01      24.7       4.98     YES       5.480      11.1920     River
# 1   5.06      22.2       9.14      NO       7.332      12.1728      Lake
# 2   4.97      22.2       4.03      NO       7.394     101.1200      None
# 3   5.96      21.3       2.94     YES       9.268      11.2672      Lake
# 4   5.86      21.3       5.33      NO       8.824      11.2896      Lake
#
#    rainfall bus_ter     parks
# 0        23     YES  0.049347
# ...

# %%
X.waterbody.value_counts()
# Out:
# River             183
# None              155
# Lake               97
# Lake and River     71
# Name: waterbody, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le1 = LabelEncoder()
le2 = LabelEncoder()

X.iloc[:,11] = le1.fit_transform(X.iloc[:,11])
X.iloc[:,-2] = le2.fit_transform(X.iloc[:,-2])
# Out:
# C:\Users\joben\AppData\Local\Temp\ipykernel_5152\1186187661.py:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X.iloc[:,11] = le1.fit_transform(X.iloc[:,11])
# C:\Users\joben\AppData\Local\Temp\ipykernel_5152\1186187661.py:7: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X.iloc[:,-2] = le2.fit_transform(X.iloc[:,-2])

# %%
X.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  dist3  \
# 0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81   4.18
# 1     0.02731       37.07     0.469     6.421  78.9   4.99   4.70   5.12
# 2     0.02729       37.07     0.469     7.185  61.1   5.03   4.86   5.01
# 3     0.03237       32.18     0.458     6.998  45.8   6.21   5.93   6.16
# 4     0.06905       32.18     0.458     7.147  54.2   6.16   5.86   6.37
#
#    dist4  teachers  poor_prop  airport  n_hos_beds  n_hot_rooms waterbody  \
# 0   4.01      24.7       4.98        1       5.480      11.1920     River
# 1   5.06      22.2       9.14        0       7.332      12.1728      Lake
# 2   4.97      22.2       4.03        0       7.394     101.1200      None
# 3   5.96      21.3       2.94        1       9.268      11.2672      Lake
# 4   5.86      21.3       5.33        0       8.824      11.2896      Lake
#
#    rainfall  bus_ter     parks
# 0        23        0  0.049347
# ...
