# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Datasets/link1/france.csv")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France

# %%
df =df.drop(['InvoiceNo','StockCode','InvoiceDate','CustomerID','Country'],axis = 1)
df
# Out:
#                           Description  Quantity  UnitPrice
# 0           ALARM CLOCK BAKELIKE PINK        24       3.75
# 1           ALARM CLOCK BAKELIKE RED         24       3.75
# 2          ALARM CLOCK BAKELIKE GREEN        12       3.75
# 3     PANDA AND BUNNIES STICKER SHEET        12       0.85
# 4                    STARS GIFT TAPE         24       0.65
# ...                               ...       ...        ...
# 8552      PACK OF 20 SPACEBOY NAPKINS        12       0.85
# 8553     CHILDREN'S APRON DOLLY GIRL          6       2.10
# 8554    CHILDRENS CUTLERY DOLLY GIRL          4       4.15
# 8555  CHILDRENS CUTLERY CIRCUS PARADE         4       4.15
# 8556    BAKING SET 9 PIECE RETROSPOT          3       4.95
#
# [8557 rows x 3 columns]

# %%
df.Description.value_counts()
# Out:
# POSTAGE                              311
# RABBIT NIGHT LIGHT                    75
# RED TOADSTOOL LED NIGHT LIGHT         72
# PLASTERS IN TIN WOODLAND ANIMALS      68
# PLASTERS IN TIN CIRCUS PARADE         68
#                                     ...
# JAZZ HEARTS ADDRESS BOOK               1
# JAZZ HEARTS PURSE NOTEBOOK             1
# HANGING HEART ZINC T-LIGHT HOLDER      1
# DRAWER KNOB CRACKLE GLAZE PINK         1
# VICTORIAN SEWING BOX LARGE             1
# Name: Description, Length: 1565, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8557 entries, 0 to 8556
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Description  8557 non-null   object
#  1   Quantity     8557 non-null   int64
#  2   UnitPrice    8557 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 200.7+ KB

# %%
categ=['Description']
for feat in categ:
    dummy = pd.get_dummies(df[feat],drop_first = True)
    df= df.drop([feat],axis = 1)
    df=pd.concat([df,dummy],axis =1)
df
# Out:
#       Quantity  UnitPrice   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# 0           24       3.75                   0                             0
# 1           24       3.75                   0                             0
# 2           12       3.75                   0                             0
# 3           12       0.85                   0                             0
# 4           24       0.65                   0                             0
# ...        ...        ...                 ...                           ...
# 8552        12       0.85                   0                             0
# 8553         6       2.10                   0                             0
# 8554         4       4.15                   0                             0
# 8555         4       4.15                   0                             0
# 8556         3       4.95                   0                             0
#
# ...

# %%
X = df.drop(['UnitPrice'],axis =1 )

# %%
X
# Out:
#       Quantity   DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# 0           24                   0                             0
# 1           24                   0                             0
# 2           12                   0                             0
# 3           12                   0                             0
# 4           24                   0                             0
# ...        ...                 ...                           ...
# 8552        12                   0                             0
# 8553         6                   0                             0
# 8554         4                   0                             0
# 8555         4                   0                             0
# 8556         3                   0                             0
#
#        NINE DRAWER OFFICE TIDY   SET 2 TEA TOWELS I LOVE LONDON   \
# 0                            0                                 0
# ...

# %%
y = df.UnitPrice.values
y
# Out:
# array([3.75, 3.75, 3.75, ..., 4.15, 4.15, 4.95])

# %%
y=y.reshape(-1,1)

# %% [markdown]
# Splitting

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 0)
X_train.isnull().sum()
# Out:
# Quantity                            0
#  DOLLY GIRL BEAKER                  0
#  I LOVE LONDON MINI BACKPACK        0
#  NINE DRAWER OFFICE TIDY            0
#  SET 2 TEA TOWELS I LOVE LONDON     0
#                                    ..
# ZINC FOLKART SLEIGH BELLS           0
# ZINC HERB GARDEN CONTAINER          0
# ZINC METAL HEART DECORATION         0
# ZINC T-LIGHT HOLDER STAR LARGE      0
# ZINC T-LIGHT HOLDER STARS SMALL     0
# Length: 1565, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss_x = StandardScaler()
ss_y = StandardScaler()

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# %%
reg.score(X_test,y_test)
# Out:
# -5.72279807482435e+17

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =2)
X_polytrain = poly.fit_transform(X_train)
X_polytest = poly.fit_transform(X_test)

polyreg = LinearRegression()
polyreg.fit(X_polytrain,y_train)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 from sklearn.preprocessing import PolynomialFeatures
#       2 poly = PolynomialFeatures(degree =2)
# ----> 3 X_polytrain = poly.fit_transform(X_train)
#       4 X_polytest = poly.fit_transform(X_test)
#       6 polyreg = LinearRegression()
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# ...

# %%
polyreg.score(X_polytest,y_test)

# %%
poly3 = PolynomialFeatures(degree =3)
X_poly3 = poly3.fit_transform(X)
polyreg3 = LinearRegression()
polyreg3.fit(X_poly3,y)

# %% [markdown]
# ## Support Vector Machines

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train,y_train)

# %%
svr.score(X_test,y_test)

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state = 0)
dtr.fit(X_train,y_train)

# %%
dtr.score(X_test,y_test)

# %% [markdown]
# ## Lasso-Ridge Regressor

# %%
from sklearn.linear_model import Ridge
ridgeR = Ridge(alpha = 15)
ridgeR.fit(X_train,y_train)

# %%
ridgeR.score(X_test,y_test)
